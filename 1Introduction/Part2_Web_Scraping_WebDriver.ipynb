# %% [markdown]
# # Introduction

# %% [markdown]
# Aujourd'hui la plupart des sites web utilisent du JavaScript pour rendre le site plus dynamique et agréable mais aussi pour afficher la données.
#
# Pour ces sites, la première méthode abordée n'est pas efficace, car de nombreuses requêtes sont utilisées pour se connecter, afficher la donnée, naviguer, il faudrait prendre en compte toutes ces requêtes et les assembler pour simuler le comportement du site.
#
# **C'est le comportement de votre navigateur**, il compile toutes les interactions, les requêtes et génère du HTML permettant d'afficher l'interface graphique d'un site web.
#
# Pour palier ce problème on peut laisser le navigateur faire son travail et contrôler sa surcouche logiciel. Pour cela on peut prendre le contrôle d'un navigateur comme Chrome, Edge, Firefox ou Safari depuis un script Python.
#
# Pour cela, nous allons utiliser un package Python `Selenium` https://selenium-python.readthedocs.io/ qui permet d'instancier un navigateur et de le contrôler. Sélénium est beaucoup utilisé pour générer des tests automatiques de sites web.
#
# On peut trouver les drivers des différents browser :
# - Chrome:	https://sites.google.com/a/chromium.org/chromedriver/downloads
# - Edge:	https://developer.microsoft.com/en-us/microsoft-edge/tools/webdriver/
# - Firefox:	https://github.com/mozilla/geckodriver/releases
# - Safari:	https://webkit.org/blog/6900/webdriver-support-in-safari-10/

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\tlg\anaconda3\lib\site-packages (3.141.0)
# Requirement already satisfied: urllib3 in c:\users\tlg\anaconda3\lib\site-packages (from selenium) (1.25.9)

# %%
from selenium import webdriver

# %%
IS_LINUX = False

# %%
chrome = webdriver.Chrome(executable_path="./chromedriver")

# %% [markdown]
# Vous devez voir apparaître une nouvelle instance de votre navigateur. Si vous voulez accéder à une page :

# %%
chrome.get("https://www.amazon.fr")

# %% [markdown]
# Allez maintenant voir votre fenêtre. Vous êtes sur le site d'amazon. Vous pouvez maintenant vous déplacer dans la page. Pour cela il va falloir inspecter le code source de la page.
#
# Il existe de nombreuse méthode pour récupérer les éléments par exemple `find_element_by_link_text` qui permet de récupérer un élément grâce au text affiché. Ici, si on veut récupérer toutes les `Ventes Flash`

# %%
link = chrome.find_element_by_link_text("Voir tout")
type(link)
# Out:
# selenium.webdriver.remote.webelement.WebElement

# %% [markdown]
# Si on veut entrer dans le lien, il suffit d'appeler la méthode `click`.

# %%
link.click()

# %% [markdown]
# Vous êtes arrivé sur la page des ventes flash. Maintenant nous allons récupérer toutes les ventes actuelles. On remarque que les ventes sont stockés dans des widgets qui porte l'id `widgetContent`.

# %%
all_widgets = chrome.find_elements_by_id("widgetContent")
type(all_widgets), len(all_widgets)
# Out:
# (list, 4)

# %% [markdown]
# On obtient une liste d'éléments décrits par cet identifiant. Il y en a 5, un pour chaque ligne. Pour récupérer les différentes offres de la première ligne. on récupère les sections correspondantes:

# %%
first_line = all_widgets[0]
all_first_line_elements = first_line.find_elements_by_class_name('a-section')
len(all_first_line_elements)
# Out:
# 160

# %% [markdown]
# Pour récupérer le text maintenant :

# %%
_ = [print(elt.text+ "\n")  for elt in all_first_line_elements]
# Out:
# OFFRE STAR
# 34,99 € - 374,99 €
# Termine dans 9:30:12
# Greenworks: jusqu'à -25% sur une sélection d'outils
# 46
# Voir l'offre
#
# OFFRE STAR
# 34,99 € - 374,99 €
# Termine dans 9:30:12
# Greenworks: jusqu'à -25% sur une sélection d'outils
# 46
# Voir l'offre
#
#
#
# OFFRE STAR
# 34,99 € - 374,99 €
# Termine dans 9:30:12
# Greenworks: jusqu'à -25% sur une sélection d'outils
# 46
# Voir l'offre
#
# OFFRE STAR
# 49,90 € - 189,90 €
# Termine dans 9:30:12
# tado°: jusqu'à -40% sur les thermostats et les têtes intellige...
# 2168
# Voir l'offre
#
# OFFRE STAR
# 49,90 € - 189,90 €
# Termine dans 9:30:12
# tado°: jusqu'à -40% sur les thermostats et les têtes intellige...
# 2168
# Voir l'offre
#
#
#
# OFFRE STAR
# 49,90 € - 189,90 €
# Termine dans 9:30:12
# tado°: jusqu'à -40% sur les thermostats et les têtes intellige...
# 2168
# Voir l'offre
#
# OFFRE STAR
# 10,25 € - 20,65 €
# Termine dans 9:25:13
# Jusqu'à -25% sur les produits de beauté et soins du corps
# 2
# Voir l'offre
#
# OFFRE STAR
# 10,25 € - 20,65 €
# Termine dans 9:25:13
# Jusqu'à -25% sur les produits de beauté et soins du corps
# 2
# Voir l'offre
#
#
#
# OFFRE STAR
# 10,25 € - 20,65 €
# Termine dans 9:25:13
# Jusqu'à -25% sur les produits de beauté et soins du corps
# 2
# Voir l'offre
#
# OFFRE STAR
# 14,99 € - 29,24 €
# Termine dans 9:25:13
# Jusqu'à -25% sur une sélection pour la voiture
# 853
# Voir l'offre
#
# OFFRE STAR
# 14,99 € - 29,24 €
# Termine dans 9:25:12
# Jusqu'à -25% sur une sélection pour la voiture
# 853
# Voir l'offre
#
#
#
# OFFRE STAR
# 14,99 € - 29,24 €
# Termine dans 9:25:12
# Jusqu'à -25% sur une sélection pour la voiture
# 853
# Voir l'offre
#
# OFFRE STAR
# 0,99 € - 2,49 €
# Termine dans 9:30:12
# Offre ebooks du 16 novembre jusqu'à -80%
# 370
# Voir l'offre
#
# OFFRE STAR
# 0,99 € - 2,49 €
# Termine dans 9:30:12
# Offre ebooks du 16 novembre jusqu'à -80%
# 370
# Voir l'offre
#
#
#
# OFFRE STAR
# 0,99 € - 2,49 €
# Termine dans 9:30:12
# Offre ebooks du 16 novembre jusqu'à -80%
# 370
# Voir l'offre
#
# OFFRE STAR
# 13,49 € - 14,99 €
# Termine dans 9:25:12
# CAMBIVO: Jusqu'à -25% sur une sélection de produits sport
# 7825
# Voir l'offre
#
# OFFRE STAR
# 13,49 € - 14,99 €
# Termine dans 9:25:12
# CAMBIVO: Jusqu'à -25% sur une sélection de produits sport
# 7825
# Voir l'offre
#
#
#
# OFFRE STAR
# 13,49 € - 14,99 €
# Termine dans 9:25:12
# CAMBIVO: Jusqu'à -25% sur une sélection de produits sport
# 7825
# Voir l'offre
#
# OFFRE STAR
# 20,00 € - 200,00 €
# Termine dans 9:30:11
# Honeywell Home: jusqu'à -30% sur une sélection maison connectée
# 15
# Voir l'offre
#
# OFFRE STAR
# 20,00 € - 200,00 €
# Termine dans 9:30:11
# Honeywell Home: jusqu'à -30% sur une sélection maison connectée
# 15
# Voir l'offre
#
#
#
# OFFRE STAR
# 20,00 € - 200,00 €
# Termine dans 9:30:11
# Honeywell Home: jusqu'à -30% sur une sélection maison connectée
# 15
# Voir l'offre
#
# 109,00 € - 399,00 €
# Xiaomi: jusqu'à -20% sur sur une sélection de smartphones
# 90
# Voir l'offre
#
# 109,00 € - 399,00 €
# Xiaomi: jusqu'à -20% sur sur une sélection de smartphones
# 90
# Voir l'offre
#
#
#
# 109,00 € - 399,00 €
# Xiaomi: jusqu'à -20% sur sur une sélection de smartphones
# 90
# Voir l'offre
#
# 219,00 € - 429,00 €
# Samsung: jusqu’à -15% sur une sélection de smartphones
# 51
# Voir l'offre
#
# 219,00 € - 429,00 €
# Samsung: jusqu’à -15% sur une sélection de smartphones
# 51
# Voir l'offre
#
#
#
# 219,00 € - 429,00 €
# Samsung: jusqu’à -15% sur une sélection de smartphones
# 51
# Voir l'offre
#
# 549,00 € - 2.199,00 €
# ASUS, HP, Dell...: jusqu'à -15% sur une sélection de PC Windows
# 12
# Voir l'offre
#
# 549,00 € - 2.199,00 €
# ASUS, HP, Dell...: jusqu'à -15% sur une sélection de PC Windows
# 12
# Voir l'offre
#
#
#
# 549,00 € - 2.199,00 €
# ASUS, HP, Dell...: jusqu'à -15% sur une sélection de PC Windows
# 12
# Voir l'offre
#
# 889,00 € - 2.419,00 €
# ASUS, HP, Dell...: jusqu'à -15% sur une sélection de PC Gaming
# 552
# Voir l'offre
#
# 889,00 € - 2.419,00 €
# ASUS, HP, Dell...: jusqu'à -15% sur une sélection de PC Gaming
# 552
# Voir l'offre
#
#
#
# 889,00 € - 2.419,00 €
# ASUS, HP, Dell...: jusqu'à -15% sur une sélection de PC Gaming
# 552
# Voir l'offre
#
# 239,99 € - 599,99 €
# Huawei: jusqu'à -20% sur des PCs et tablettes
# 11249
# Voir l'offre
#
# 239,99 € - 599,99 €
# Huawei: jusqu'à -20% sur des PCs et tablettes
# 11249
# Voir l'offre
#
#
#
# 239,99 € - 599,99 €
# Huawei: jusqu'à -20% sur des PCs et tablettes
# 11249
# Voir l'offre
#
# 649,00 €
# Prix conseillé : 699,00 € (-7%)
# Chromebook :-50€ sur un ordinateur portable HP
# 745
# Voir l'offre
#
# 649,00 €
# Prix conseillé : 699,00 € (-7%)
# Chromebook :-50€ sur un ordinateur portable HP
# 745
# Voir l'offre
#
#
#
# 649,00 €
# Prix conseillé : 699,00 € (-7%)
# Chromebook :-50€ sur un ordinateur portable HP
# 745
# Voir l'offre
#
# 66,99 € - 749,99 €
# Western Digital: Jusqu'à -30% sur une sélection de produits
# 87232
# Voir l'offre
#
# 66,99 € - 749,99 €
# Western Digital: Jusqu'à -30% sur une sélection de produits
# 87232
# Voir l'offre
#
#
#
# 66,99 € - 749,99 €
# Western Digital: Jusqu'à -30% sur une sélection de produits
# 87232
# Voir l'offre
#
# 17,99 € - 99,99 €
# Oral-B: Jusqu'à -35% sur les brosses à dents électriques Pro et Smart
# 2315
# Voir l'offre
#
# 17,99 € - 99,99 €
# Oral-B: Jusqu'à -35% sur les brosses à dents électriques Pro et Smart
# 2315
# Voir l'offre
#
#
#
# 17,99 € - 99,99 €
# Oral-B: Jusqu'à -35% sur les brosses à dents électriques Pro et Smart
# 2315
# Voir l'offre
#
# 32,99 € - 139,99 €
# Philips: Jusqu'à -50% sur les produits de Rasage pour Homme
# 3182
# Voir l'offre
#
# 32,99 € - 139,99 €
# Philips: Jusqu'à -50% sur les produits de Rasage pour Homme
# 3182
# Voir l'offre
#
#
#
# 32,99 € - 139,99 €
# Philips: Jusqu'à -50% sur les produits de Rasage pour Homme
# 3182
# Voir l'offre
#
# 25,99 € - 37,09 €
# Pampers : jusqu'à -30% sur les couches & couche-culottes
# 8525
# Voir l'offre
#
# 25,99 € - 37,09 €
# Pampers : jusqu'à -30% sur les couches & couche-culottes
# 8525
# Voir l'offre
#
#
#
# 25,99 € - 37,09 €
# Pampers : jusqu'à -30% sur les couches & couche-culottes
# 8525
# Voir l'offre
#
# 69,99 €
# Prix conseillé : 119,99 € (-42%)
# Rowenta Compact Power Cyclonic Aspirateur Sans Sac
# Vendu et expédié par Amazon.fr
# 12218
# Ajouter au panier
#
# 69,99 €
# Prix conseillé : 119,99 € (-42%)
# Rowenta Compact Power Cyclonic Aspirateur Sans Sac
# Vendu et expédié par Amazon.fr
# 12218
# Ajouter au panier
#
#
#
# 69,99 €
# Prix conseillé : 119,99 € (-42%)
# Rowenta Compact Power Cyclonic Aspirateur Sans Sac
# Vendu et expédié par Amazon.fr
# 12218
# Ajouter au panier
#
# 13,13 € - 39,06 €
# L'Or, Senseo, Tassimo : jusqu'à -30% sur les capsules, dosettes et café en grains
# 10
# Voir l'offre
#
# 13,13 € - 39,06 €
# L'Or, Senseo, Tassimo : jusqu'à -30% sur les capsules, dosettes et café en grains
# 10
# Voir l'offre
#
#
#
# 13,13 € - 39,06 €
# L'Or, Senseo, Tassimo : jusqu'à -30% sur les capsules, dosettes et café en grains
# 10
# Voir l'offre
#
# 18,99 € - 129,99 €
# Philips Sonicare : jusqu'à -40% sur les brosses à dents électriques et les têtes de brosse
# 5186
# Voir l'offre
#
# 18,99 € - 129,99 €
# Philips Sonicare : jusqu'à -40% sur les brosses à dents électriques et les têtes de brosse
# 5186
# Voir l'offre
#
#
#
# 18,99 € - 129,99 €
# Philips Sonicare : jusqu'à -40% sur les brosses à dents électriques et les têtes de brosse
# 5186
# Voir l'offre
#
# 14,99 € - 99,99 €
# Philips Avent: Jusqu'à -40% sur les produits pour Bébé
# 10672
# Voir l'offre
#
# 14,99 € - 99,99 €
# Philips Avent: Jusqu'à -40% sur les produits pour Bébé
# 10672
# Voir l'offre
#
#
#
# 14,99 € - 99,99 €
# Philips Avent: Jusqu'à -40% sur les produits pour Bébé
# 10672
# Voir l'offre
#
# 8,99 € - 155,99 €
# Jusqu'à -35% sur une sélection de casques et lunettes de ski
# 3
# Voir l'offre
#
# 8,99 € - 155,99 €
# Jusqu'à -35% sur une sélection de casques et lunettes de ski
# 3
# Voir l'offre
#
#
#
# 8,99 € - 155,99 €
# Jusqu'à -35% sur une sélection de casques et lunettes de ski
# 3
# Voir l'offre
#
# 19,99 € - 359,99 €
# Sandisk: Jusqu'à -55% sur une sélection de produits
# 44409
# Voir l'offre
#
# 19,99 € - 359,99 €
# Sandisk: Jusqu'à -55% sur une sélection de produits
# 44409
# Voir l'offre
#
#
#
# 19,99 € - 359,99 €
# Sandisk: Jusqu'à -55% sur une sélection de produits
# 44409
# Voir l'offre
#
# 10,99 € - 169,99 €
# Trust: jusqu'à -30% sur les accessoires PC & Gaming
# 951
# Voir l'offre
#
# 10,99 € - 169,99 €
# Trust: jusqu'à -30% sur les accessoires PC & Gaming
# 951
# Voir l'offre
#
#
#
# 10,99 € - 169,99 €
# Trust: jusqu'à -30% sur les accessoires PC & Gaming
# 951
# Voir l'offre
#
# 2,80 € - 8,30 €
# Rimmel, Sally Hanson: jusqu'à -30% sur une sélection de vernis et soins des ongles
# 7470
# Voir l'offre
#
# 2,80 € - 8,30 €
# Rimmel, Sally Hanson: jusqu'à -30% sur une sélection de vernis et soins des ongles
# 7470
# Voir l'offre
#
#
#
# 2,80 € - 8,30 €
# Rimmel, Sally Hanson: jusqu'à -30% sur une sélection de vernis et soins des ongles
# 7470
# Voir l'offre
#
# 34,99 € - 199,99 €
# Philips: Jusqu'à -40% sur les produits Beauté et Luminothérapie
# 1417
# Voir l'offre
#
# 34,99 € - 199,99 €
# Philips: Jusqu'à -40% sur les produits Beauté et Luminothérapie
# 1417
# Voir l'offre
#
#
#
# 34,99 € - 199,99 €
# Philips: Jusqu'à -40% sur les produits Beauté et Luminothérapie
# 1417
# Voir l'offre
#
# 31,99 € - 49,99 €
# Brita: jusqu'à -29% sur une sélection des carafes filtrantes
# 6132
# Voir l'offre
#
# 31,99 € - 49,99 €
# Brita: jusqu'à -29% sur une sélection des carafes filtrantes
# 6132
# Voir l'offre
# 31,99 € - 49,99 €
# Brita: jusqu'à -29% sur une sélection des carafes filtrantes
# 6132
# Voir l'offre
#
# 14,90 € - 44,90 €
# TP-Link : Jusqu'à -38% sur une sélection de produits
# 3877
# Voir l'offre
#
# 14,90 € - 44,90 €
# TP-Link : Jusqu'à -38% sur une sélection de produits
# 3877
# Voir l'offre
#
#
#
# 14,90 € - 44,90 €
# TP-Link : Jusqu'à -38% sur une sélection de produits
# 3877
# Voir l'offre
#
# 189,00 €
# Prix : 257,10 € (-26%)
# iRobot : Roomba 671, Aspirateur Robot
# Vendu et expédié par Amazon.fr
# 6778
# Ajouter au panier
#
# 189,00 €
# Prix : 257,10 € (-26%)
# iRobot : Roomba 671, Aspirateur Robot
# Vendu et expédié par Amazon.fr
# 6778
# Ajouter au panier
#
#
#
# 189,00 €
# Prix : 257,10 € (-26%)
# iRobot : Roomba 671, Aspirateur Robot
# Vendu et expédié par Amazon.fr
# 6778
# Ajouter au panier
#
# 5,69 € - 149,59 €
# Ellison: jusqu'à -40% sur une sélection de produits
# 627
# Voir l'offre
#
# 5,69 € - 149,59 €
# Ellison: jusqu'à -40% sur une sélection de produits
# 627
# Voir l'offre
#
#
#
# 5,69 € - 149,59 €
# Ellison: jusqu'à -40% sur une sélection de produits
# 627
# Voir l'offre
#
# 179,99 €
# Prix conseillé : 299,99 € (-40%)
# Rowenta Air Force 360 Car Care Aspirateur Balai sans Fil Multifonc...
# Vendu et expédié par Amazon.fr
# 1420
# Ajouter au panier
#
# 179,99 €
# Prix conseillé : 299,99 € (-40%)
# Rowenta Air Force 360 Car Care Aspirateur Balai sans Fil Multifonc...
# Vendu et expédié par Amazon.fr
# 1420
# Ajouter au panier
#
#
#
# 179,99 €
# Prix conseillé : 299,99 € (-40%)
# Rowenta Air Force 360 Car Care Aspirateur Balai sans Fil Multifonc...
# Vendu et expédié par Amazon.fr
# 1420
# Ajouter au panier
#
# 109,99 € - 379,99 €
# Western Digital & SanDisk: Jusqu'à -30% sur une sélection de SSD externes
# 24696
# Voir l'offre
#
# 109,99 € - 379,99 €
# Western Digital & SanDisk: Jusqu'à -30% sur une sélection de SSD externes
# 24696
# Voir l'offre
#
#
#
# 109,99 € - 379,99 €
# Western Digital & SanDisk: Jusqu'à -30% sur une sélection de SSD externes
# 24696
# Voir l'offre
#
# 19,99 € - 25,99 €
# Nutribullet: jusqu'à -30% sur une sélection de produits
# 291
# Voir l'offre
#
# 19,99 € - 25,99 €
# Nutribullet: jusqu'à -30% sur une sélection de produits
# 291
# Voir l'offre
#
#
#
# 19,99 € - 25,99 €
# Nutribullet: jusqu'à -30% sur une sélection de produits
# 291
# Voir l'offre
#
# 13,99 € - 41,99 €
# Prix conseillé : 19,99 € - 59,99 € (-30%)
# REMINGTON: jusqu'à -30% sur une sélection de d'accessoires soin des cheveux
# 7909
# Voir l'offre
#
# 13,99 € - 41,99 €
# Prix conseillé : 19,99 € - 59,99 € (-30%)
# REMINGTON: jusqu'à -30% sur une sélection de d'accessoires soin des cheveux
# 7909
# Voir l'offre
#
#
#
# 13,99 € - 41,99 €
# Prix conseillé : 19,99 € - 59,99 € (-30%)
# REMINGTON: jusqu'à -30% sur une sélection de d'accessoires soin des cheveux
# 7909
# Voir l'offre
#
# 16,99 € - 61,99 €
# Wenko: jusqu'à -40% sur une sélection d'accéssoires pour le linge
# 1060
# Voir l'offre
#
# 16,99 € - 61,99 €
# Wenko: jusqu'à -40% sur une sélection d'accéssoires pour le linge
# 1060
# Voir l'offre
#
#
#
# 16,99 € - 61,99 €
# Wenko: jusqu'à -40% sur une sélection d'accéssoires pour le linge
# 1060
# Voir l'offre
#
# 149,00 € - 649,00 €
# Huawei: jusqu'à -25% sur des smartphones et objets connectés
# 4459
# Voir l'offre
#
# 149,00 € - 649,00 €
# Huawei: jusqu'à -25% sur des smartphones et objets connectés
# 4459
# Voir l'offre
#
#
#
# 149,00 € - 649,00 €
# Huawei: jusqu'à -25% sur des smartphones et objets connectés
# 4459
# Voir l'offre
#
# 79,90 €
# Prix conseillé : 199,99 € (-60%)
# Nespresso : Jusqu'à -60% sur les gammes Vertuo
# 1096
# Voir l'offre
#
# 79,90 €
# Prix conseillé : 199,99 € (-60%)
# Nespresso : Jusqu'à -60% sur les gammes Vertuo
# 1096
# Voir l'offre
#
#
#
# 79,90 €
# Prix conseillé : 199,99 € (-60%)
# Nespresso : Jusqu'à -60% sur les gammes Vertuo
# 1096
# Voir l'offre
#
# 31,29 € - 89,90 €
# Nania: jusqu'à -20% sur les sièges auto et poussettes
# 373
# Voir l'offre
#
# 31,29 € - 89,90 €
# Nania: jusqu'à -20% sur les sièges auto et poussettes
# 373
# Voir l'offre
#
#
#
# 31,29 € - 89,90 €
# Nania: jusqu'à -20% sur les sièges auto et poussettes
# 373
# Voir l'offre
#
# 169,00 € - 949,00 €
# OPPO : Jusqu'à -20% sur les smartphones débloqués
# 35
# Voir l'offre
#
# 169,00 € - 949,00 €
# OPPO : Jusqu'à -20% sur les smartphones débloqués
# 35
# Voir l'offre
#
#
#
# 169,00 € - 949,00 €
# OPPO : Jusqu'à -20% sur les smartphones débloqués
# 35
# Voir l'offre
#
# 749,00 € - 849,00 €
# OnePlus: jusqu'à -17% sur une sélection de smartphones
# 210
# Voir l'offre
#
# 749,00 € - 849,00 €
# OnePlus: jusqu'à -17% sur une sélection de smartphones
# 210
# Voir l'offre
#
#
#
# 749,00 € - 849,00 €
# OnePlus: jusqu'à -17% sur une sélection de smartphones
# 210
# Voir l'offre

# %%
print(all_first_line_elements[0].text)
# Out:
# OFFRE STAR
# 34,99 € - 374,99 €
# Termine dans 9:30:08
# Greenworks: jusqu'à -25% sur une sélection d'outils
# 46
# Voir l'offre

# %%
test = all_first_line_elements[0].find_elements_by_id('dealImage')
t0 = test[0]
print(t0.get_attribute('href'))#href, src
# Out:
# https://www.amazon.fr/deal/99ab6fd1/ref=gbps_img___99ab6fd1?showVariations=true&smid=A1X6FK5RDHNB96

# %% [markdown]
# Si vous êtes fan de JavaScript vous pouvez même injecter du code JS dans le navigateur depuis Python pour exécuter des opérations complexes.

# %%
js_script = """
const class_name = 'DRIOC'
console.log(`Hi from ${class_name}`)
"""

# %%
chrome.execute_script(js_script)

# %% [markdown]
# Vous pouvez aller vérifier dans la console Javascript du navigateur que le message apparait bien.

# %% [markdown]
# # Exercice

# %% [markdown]
# ## Exercice 1

# %% [markdown]
# Extraire le prix des offres :

# %%
def extract_price(offer_web_element):
    tab = offer_web_element.find_elements_by_class_name('dealPriceText')
    return tab[0].text

extract_price(all_first_line_elements[0])
# Out:
# '34,99 € - 374,99 €'

# %% [markdown]
# Extraire l'image de l'offre:

# %%
def extract_image(offer_web_element):
    tab = offer_web_element.find_elements_by_tag_name('img')
    return tab[0].get_attribute('src')

extract_image(all_first_line_elements[0])
# Out:
# 'https://m.media-amazon.com/images/G/29/tools/24VITAGW._AA210_.png'

# %% [markdown]
# Extraire le titre de l'offre:

# %%
def extract_title(offer_web_element):
    tab = offer_web_element.find_elements_by_id('dealTitle')
    return tab[0].text

extract_title(all_first_line_elements[0])
# Out:
# "Greenworks: jusqu'à -25% sur une sélection d'outils"

# %%
chrome.close()
